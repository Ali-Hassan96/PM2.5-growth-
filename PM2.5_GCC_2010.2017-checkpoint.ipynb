# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import altair as alt
import seaborn as sns

# %%
df = pd.read_csv("PM2.5_GCC.csv")
df
# Out:
#            Country Name Country Code  \
# 0          Saudi Arabia          SAU
# 1                 Qatar          QAT
# 2                  Oman          OMN
# 3               Bahrain          BHR
# 4  United Arab Emirates          UAE
# 5                Kuwait          KWT
#
#                                          Series Name        Series Code  \
# 0  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# 1  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M4
# 2  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M5
# 3  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M6
# 4  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M7
# 5  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M8
#
#         2010       2011       2012       2013       2014       2015  \
# 0  81.699182  82.419032  85.513303  83.630992  75.608441  97.432289
# ...

# %%
df.dtypes
# Out:
# Country Name     object
# Country Code     object
# Series Name      object
# Series Code      object
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# dtype: object

# %%
Average = df.mean(axis=1)
Average
# Out:
# C:\Users\aliha\AppData\Local\Temp/ipykernel_21744/946582955.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Average = df.mean(axis=1)
# 0    84.839308
# 1    87.022488
# 2    40.205135
# 3    67.936144
# 4    39.852101
# 5    61.858825
# dtype: float64

# %%
df['Average'] = [84.839308, 87.022488, 40.205135,  67.936144, 39.852101,  61.858825]
df
# Out:
#            Country Name Country Code  \
# 0          Saudi Arabia          SAU
# 1                 Qatar          QAT
# 2                  Oman          OMN
# 3               Bahrain          BHR
# 4  United Arab Emirates          UAE
# 5                Kuwait          KWT
#
#                                          Series Name        Series Code  \
# 0  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# 1  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M4
# 2  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M5
# 3  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M6
# 4  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M7
# 5  PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M8
#
#         2010       2011       2012       2013       2014       2015  \
# 0  81.699182  82.419032  85.513303  83.630992  75.608441  97.432289
# ...

# %%
df.plot(x="Country Name", y=["2010",'2011','2012','2013','2014','2015','2016','2017'],
        kind="bar", figsize=(20, 10),fontsize=20 )
# Out:
# <AxesSubplot:xlabel='Country Name'>

# %%
labels = 'Saudi Arabia', 'Qatar', 'Oman', 'Bahrain', 'United Arab Emirates', 'Kuwait'
sizes = [84.8, 87.0, 40.2,  67.9, 39.8, 61.8]
explode = (0.1, 0, 0, 0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

plt.rcParams['font.size'] = 30
fig1, ax1 = plt.subplots(figsize=(15, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=180, textprops={'fontsize': 20})
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('The avrearge of PM2.5 from 2010 to 2017 in GCC countries', loc='center')
plt.show()

# %%
plt.plot(df['2017'], df['Country Name'], color='red', marker='o')
plt.title('Country and the pollution rate ', fontsize=14)
plt.xlabel('2017', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.grid(True)
plt.show()

# %%
labels = ['2010', '2011','2012', '2013', '2014', '2015', '2016', '2017']
KSA = [81, 82, 85, 83, 75, 97, 84, 87]
QAT = [84, 81, 89, 88, 78, 94, 88, 91]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(25, 15))
rects1 = ax.bar(x - width/2, KSA, width, label='KSA')
rects2 = ax.bar(x + width/2, QAT, width, label='QAT')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('pollution rate')
ax.set_title('KSA VS QAT IN pollution growth ')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()



plt.show()

# %%
plt.style.use('seaborn-darkgrid')
labels = ['2013', '2014', '2015', '2016', '2017']
KSA = [83, 75, 97, 84, 87]
QAT = [88, 78, 94, 88, 91]
plt.figure(figsize=(25,15))
plt.bar(labels,KSA,label = "KSA",width = 0.5,color = '#FF6F00')
plt.bar(labels,QAT,label = "QAT",width = 0.5 ,bottom = KSA , color = '#FFB300')
plt.xlabel('$X$')
plt.ylabel('$Y$')
plt.title ('KSA VS QAT IN pollution growth')
for x,y in zip(labels,KSA):
    plt.text(x, y-10, '%d' % y, ha='center' , va= 'bottom')

for x,y,z in zip(labels,QAT,KSA):
    plt.text(x, y+z-10, '%d' % y, ha='center' , va= 'bottom')
        
plt.legend()
plt.savefig("STACKBAR.png", bbox_inches = 'tight')
plt.show()

# %%
# Displaying values at the top of the Grouped Bar Chart using plt.text()
plt.figure(figsize=(35,25))

# set width of bar
barWidth = 0.25

KSA = [83, 75, 97, 84, 87]
QAT = [88, 78, 94, 88, 91]
UAE = [39, 37, 42, 40, 40]

pos1 = np.arange(len(KSA))
pos2 = [x + barWidth for x in pos1]
pos3 = [x + barWidth for x in pos2]

# Make the plot
plt.bar(pos1, KSA, color='#FBC02D', width=barWidth, label='KSA')
plt.bar(pos2, QAT, color='#F57F17', width=barWidth, label='QAT')
plt.bar(pos3, UAE, color='#E65100', width=barWidth, label='UAE')

# Add xticks on the middle of the group bars
plt.xlabel('Year', fontweight='bold')
plt.ylabel('pollution rate', fontweight='bold')
plt.xticks([i + barWidth for i in range(len(KSA))], ['2013', '2014', '2015', '2016', '2017'])

for x,y in zip(pos1,KSA):
    plt.text(x, y, '%d' % y, ha='center' , va= 'bottom')
    
for x,y in zip(pos2,QAT):
    plt.text(x, y, '%d' % y, ha='center' , va= 'bottom')  
    
for x,y in zip(pos3,UAE):
    plt.text(x, y, '%d' % y, ha='center' , va= 'bottom')    
    
plt.title ('KSA VS QAT VS UAE IN pollution growth')

# Create legend & Show graphic
plt.legend()
plt.savefig("KSA VS QAT VS UAE.png", bbox_inches = 'tight')
plt.show()

# %%
plt.figure(figsize=(25,15))
KSA = [83, 75, 97, 84, 87]
labels = ['2013', '2014', '2015', '2016', '2017']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043', '#7FFF00']
plt.pie (KSA , labels= labels , colors= colors , startangle=45, autopct='%1.1f%%', pctdistance=0.85, explode=[0,0 , 0.1 , 0, 0])
my_circle=plt.Circle( (0,0), 0.7, color='white') # Adding circle at the centre
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title ('KSA pollution growth')
plt.show()

# %%
from matplotlib.patches import ConnectionPatch

# make figure and assign axis objects
fig = plt.figure(figsize=(15, 9))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
fig.subplots_adjust(wspace=0)

# pie chart parameters
ratios = [84.8, 87.0, 40.2,  67.9, 39.8,  61.8]
labels = ['Saudi Arabia', 'Qatar', 'Oman', 'Bahrain', 'United Arab Emirates', 'Kuwait']
explode = [0.1, 0, 0, 0, 0, 0]
# rotate so that first wedge is split by the x-axis
angle = -60 * ratios[0]
ax1.pie(ratios, autopct='%1.1f%%', startangle=angle,
        labels=labels, explode=explode, textprops={'fontsize': 22})

# bar chart parameters

xpos = 0
bottom = 0
ratios = [.75, .97, .84, .87]
width = .2
colors = ['#FFA500','#800000','#008000','#FF0000']

for j in range(len(ratios)):
    height = ratios[j]
    ax2.bar(xpos, height, width, bottom=bottom, color=colors[j])
    ypos = bottom + ax2.patches[j].get_height() / 2
    bottom += height
    ax2.text(xpos, ypos, "%d%%" % (ax2.patches[j].get_height() * 100),
             ha='center')
ax2.set_title('Precantge for pm2.5 for KSA')
ax2.legend(('2014', '2015', '2016', '2017'))
ax2.axis('off')
ax2.set_xlim(- 1.5 * width, 1.5 * width)
# use ConnectionPatch to draw lines between the two plots
# get the wedge data
theta1, theta2 = ax1.patches[0].theta1, ax1.patches[0].theta2
center, r = ax1.patches[0].center, ax1.patches[0].r
bar_height = sum([item.get_height() for item in ax2.patches])

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(- width / 2, bar_height), xyB=(x, y),
                      coordsA="data", coordsB="data", axesA=ax2, axesB=ax1)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(- width / 2, 0), xyB=(x, y), coordsA="data",
                      coordsB="data", axesA=ax2, axesB=ax1)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.show()
